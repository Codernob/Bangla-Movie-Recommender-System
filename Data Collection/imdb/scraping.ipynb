# %%
import requests
from bs4 import BeautifulSoup
from dateutil.parser import parse
import concurrent.futures
import pandas as pd

# %%
movie_title_arr = []
movie_year_arr = []
movie_genre_arr = []
movie_synopsis_arr =[]
image_url_arr  = []
image_id_arr = []
director_arr = []
cast_arr = []

# %%
def getMovieTitle(header):
    try:
        return header[0].find("a").getText()
    except:
        return 'NA'

def getReleaseYear(header):
    try:
        return header[0].find("span",  {"class": "lister-item-year text-muted unbold"}).getText()
    except:
        return 'NA'

def getGenre(muted_text):
    try:
        return muted_text.find("span",  {"class":  "genre"}).getText()
    except:
        return 'NA'

def getsynopsys(movie):
    try:
        return movie.find_all("p", {"class":  "text-muted"})[1].getText()
    except:
        return 'NA'

def getImage(image):
    try:
        return image.get('loadlate')
    except:
        return 'NA'

def getImageId(image):
    try:
        return image.get('data-tconst')
    except:
        return 'NA'

# %%
def main(imdb_url):
    response = requests.get(imdb_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Movie Name
    movies_list  = soup.find_all("div", {"class": "lister-item mode-advanced"})
    
    for movie in movies_list:
        header = movie.find_all("h3", {"class":  "lister-item-header"})
        muted_text = movie.find_all("p", {"class":  "text-muted"})[0]
        imageDiv =  movie.find("div", {"class": "lister-item-image float-left"})
        image = imageDiv.find("img", "loadlate")
        
        #  Movie Title
        movie_title =  getMovieTitle(header)
        movie_title_arr.append(movie_title)
        
        #  Movie release year
        year = getReleaseYear(header)
        movie_year_arr.append(year)
        
        #  Genre  of movie
        genre = getGenre(muted_text)
        movie_genre_arr.append(genre)
        
        # Movie Synopsys
        synopsis = getsynopsys(movie)
        movie_synopsis_arr.append(synopsis)
        
        #  Image attributes
        img_url = getImage(image)
        image_url_arr.append(img_url)
        
        image_id = image.get('data-tconst')
        image_id_arr.append(image_id)

# %%
# An array to store all the URL that are being queried
imageArr = []

# Maximum number of pages one wants to iterate over
MAX_PAGE =11

# Loop to generate all the URLS.
for i in range(0,MAX_PAGE):
    totalRecords = 0 if i==0 else (250*i)+1
    print(totalRecords)
    #imdb_url = f'https://www.imdb.com/search/title/?release_date=2020-01-02,2021-02-01&user_rating=4.0,10.0&languages=en&count=250&start={totalRecords}&ref_=adv_nxt'
    imdb_url = f'https://www.imdb.com/search/title/?languages=bn&sort=user_rating&title_type=feature&count=250&start={totalRecords}&ref_=adv_nxt'
    imageArr.append(imdb_url)
# Out:
# 0
# 251
# 501
# 751
# 1001
# 1251
# 1501
# 1751
# 2001
# 2251
# 2501

# %%
# Maximum number of threads that will be spawned
MAX_THREADS = 50
def download_stories(story_urls):
    threads = min(MAX_THREADS, len(story_urls))
    with concurrent.futures.ThreadPoolExecutor(max_workers=threads) as executor:
        executor.map(main, story_urls)

# %%
# Call the download function with the array of URLS called imageArr
download_stories(imageArr)

# Attach all the data to the pandas dataframe. You can optionally write it to a CSV file as well
movieDf = pd.DataFrame({
    "Title": movie_title_arr,
    "Release_Year": movie_year_arr,
    "Genre": movie_genre_arr,
    "Synopsis": movie_synopsis_arr,
    "image_url": image_url_arr,
    "image_id": image_id_arr,
})

print('--------- Download Complete CSV Formed --------')
# Out:
# --------- Download Complete CSV Formed --------
#                  Title Release_Year                        Genre  \
# 0        Gohine Shobdo       (2010)  \nAction, Drama
# 1             Ghatkali       (1979)         \nComedy
# 2  Shashi Babur Sansar       (1959)          \nDrama
# 3      Natun Diner Alo       (1973)          \nDrama
# 4               Tonsil       (1956)          \nDrama
#
#                                             Synopsis  \
# 0  \nDream of the third world country is always b...
# 1  \nPravanjan Haldar was a professional matchmak...
# 2  \nSashibhushan who is the orthodox patriarch h...
# 3                                     \nAdd a Plot\n
# 4                                     \nAdd a Plot\n
#
#                                            image_url   image_id
# 0  https://m.media-amazon.com/images/M/MV5BOWNmMT...  tt1728125
# 1  https://m.media-amazon.com/images/M/MV5BNzBlNj...  tt1587158
# 2  https://m.media-amazon.com/images/M/MV5BMzNhMW...  tt1582602
# 3  https://m.media-amazon.com/images/M/MV5BY2Y4NT...  tt1548615
# 4  https://m.media-amazon.com/images/S/sash/NapCx...  tt1534555

# %%
# movie.to_csv('file.csv', index=False) : If you want to store the file.
movieDf.head(20)
# Out:
#                      Title Release_Year  \
# 0            Gohine Shobdo       (2010)
# 1                 Ghatkali       (1979)
# 2      Shashi Babur Sansar       (1959)
# 3          Natun Diner Alo       (1973)
# 4                   Tonsil       (1956)
# 5               Paka Dekha       (1980)
# 6              Ananda Mela       (1976)
# 7         Neel Rajar Deshe       (2008)
# 8          Tollywood Focus       (2008)
# 9                    Magic   (I) (2021)
# 10                   Sathi       (2002)
# 11                   Khela       (2008)
# 12  Nirbandhamer Jora Khun       (2020)
# 13   Probhu Noshto Hoi Jai       (2007)
# 14          Baksha Rahasya       (1996)
# 15        Pothe Holo Dekha       (1988)
# 16              Buro Sadhu       (2019)
# 17                   Gondi       (2020)
# 18        Baidurya Rahasya       (1985)
# 19    Golapi Ekhon Bilatey       (2010)
#
#                                          Genre  \
# 0                  \nAction, Drama
# 1                         \nComedy
# 2                          \nDrama
# 3                          \nDrama
# 4                          \nDrama
# 5                          \nDrama
# 6                          \nDrama
# 7                      \nAdventure
# 8                          \nDrama
# 9                         \nAction
# 10       \nDrama, Musical, Romance
# 11                 \nComedy, Drama
# 12                                          NA
# 13                         \nDrama
# 14  \nAdventure, Mystery, Thriller
# 15                                          NA
# 16                         \nDrama
# 17                         \nDrama
# 18                      \nThriller
# 19                       \nMusical
#
#                                              Synopsis  \
# 0   \nDream of the third world country is always b...
# 1   \nPravanjan Haldar was a professional matchmak...
# 2   \nSashibhushan who is the orthodox patriarch h...
# 3                                      \nAdd a Plot\n
# 4                                      \nAdd a Plot\n
# 5   \nThis is a romantic comedy. Utpal Dutta, a st...
# 6         \nA person leaves everything for his love .
# 7                                      \nAdd a Plot\n
# 8                                      \nAdd a Plot\n
# 9   \nA thrilling tale of two people going through...
# 10  \nA man sacrifices everything for his love, bu...
# 11  \nKolkata-based Sheela Bhowmik feels isolated ...
# 12                                     \nAdd a Plot\n
# 13                                     \nAdd a Plot\n
# 14  \nFamous Bengali private investigator Pradosh ...
# 15                                     \nAdd a Plot\n
# 16  \nBuro Sadhu is a film which speaks about a ma...
# 17  \nHow friendship is meaningful in our life? Do...
# 18                                     \nAdd a Plot\n
# 19                                     \nAdd a Plot\n
#
#                                             image_url    image_id
# 0   https://m.media-amazon.com/images/M/MV5BOWNmMT...   tt1728125
# 1   https://m.media-amazon.com/images/M/MV5BNzBlNj...   tt1587158
# 2   https://m.media-amazon.com/images/M/MV5BMzNhMW...   tt1582602
# 3   https://m.media-amazon.com/images/M/MV5BY2Y4NT...   tt1548615
# 4   https://m.media-amazon.com/images/S/sash/NapCx...   tt1534555
# 5   https://m.media-amazon.com/images/M/MV5BM2MxNj...   tt1523525
# 6   https://m.media-amazon.com/images/S/sash/NapCx...   tt1519248
# 7   https://m.media-amazon.com/images/M/MV5BZDgwZD...   tt1422708
# 8   https://m.media-amazon.com/images/S/sash/NapCx...   tt1418761
# 9   https://m.media-amazon.com/images/M/MV5BNDdjZW...  tt14045100
# 10  https://m.media-amazon.com/images/M/MV5BYWVmZj...   tt1390851
# 11  https://m.media-amazon.com/images/M/MV5BN2FmOD...   tt1368102
# 12  https://m.media-amazon.com/images/M/MV5BMTFjNm...  tt13370848
# 13  https://m.media-amazon.com/images/M/MV5BYmU5Yj...   tt1269579
# 14  https://m.media-amazon.com/images/M/MV5BMGRhOG...   tt1159914
# 15  https://m.media-amazon.com/images/S/sash/NapCx...   tt1071338
# 16  https://m.media-amazon.com/images/M/MV5BZjg5ZT...  tt10636632
# 17  https://m.media-amazon.com/images/M/MV5BOTg4NT...  tt10122618
# 18  https://m.media-amazon.com/images/S/sash/NapCx...  tt10050946
# 19  https://m.media-amazon.com/images/S/sash/NapCx...   tt0466553
